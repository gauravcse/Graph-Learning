# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import networkx as nx
import Queue
from math import sqrt

training_data = list()

def Train(graph) :
	training_data.append(graph)

class KNN(object) :
	def __init__(self,n,m,kavg,kmin,kmax,deg,K = 10) :
		self.nodes = n
		self.edges = m
		self.average_degree = kavg
		self.neighbours = K
		self.q = Queue.PriorityQueue(self.neighbours)
		self.k_min = kmin
		self.k_max = kmax
		self.deg = deg
		
	def compute_distance(self,g) :
		return sqrt(((g.average_degree() - self.average_degree)**2) + ((g.get_edges() - self.edges)**2) + ((g.get_nodes() - self.nodes)**2) + ((g.get_kmin() - self.k_min)**2) + ((g.get_kmax() - self.k_max)**2) )

	def train(self,data) :
		self.training_data = data
		for graph in self.training_data :
			euclidian_distance = self.compute_distance(graph)
			if self.q.full() == False :
				tup = (-1*euclidian_distance,graph)
				self.q.put(tup)
			elif self.q.full() == True :
				tup1 = self.q.get()
				tup2  = (-1*euclidian_distance,graph)
				if (tup1[0] < tup2[0]) :
					self.q.put(tup2)
				elif (tup1[0] >= tup2[0]) :
					self.q.put(tup1)

	def test(self) :
		self.prediction = 0.0
		count = 0
#		print 'SELF DEGREE : {}\n'.format(self.deg)
		for i in xrange(self.neighbours) :
			add = 0.0
			tup = self.q.get_nowait()
#			print 'DISTANCE : {}'.format(tup[0])
			g = tup[1]
#			print g.get_degreerank()
			self.rank = g.get_degreerank()		# DICT : degree : rank
			'''for key in sorted(self.rank.keys(),reverse = True) :
				self.rank[key] = add
				add += g.degree_count[key]'''
			degree = self.rank.keys()
			'''for key in self.rank.keys() :
				if abs(key - self.deg) < minimum :
					minimum = key'''
                        difference = list()
                        count = 0
                        for each in degree :
                                difference.append((abs(each - self.deg),count))
                                count += 1
                        difference.sort()
                        local_rank = 0    #FOR CALCULATING RANK (WEIGHTED) WITH RESPECT TO DEGREE
                        '''for it in xrange(3) :
                                d = degree[difference[it][1]]  #THIS GIVES US THE DEGREE WHICH CAN HELP US IN GETTING THE RANK CORRESPONDING TO THE DEGREE
                                local_rank = local_rank + (self.rank[d]*(3-it))
                                print 'DEGREE : {} LOCAL RANK : {}'.format(d,self.rank[d])
                        local_rank = (float(local_rank) / 6.0)'''
                        local_rank = self.rank[degree[difference[0][1]]]
#			print 'MIN : {}\n'.format(local_rank)
			self.prediction += (local_rank*(i+1))
#			print 'SELF.PREDICTION : {}'.format(self.prediction)
		return ((float(self.prediction))/(self.neighbours*(self.neighbours+1)/2.0))
		

class BA_Graph(object) :
    def __init__(self,n,m) :
        self.graph = nx.barabasi_albert_graph(n,m)
        self.nodes = n
        self.edges = m
    def average_degree(self) :
        self.deg = sum(self.graph.degree())
        return (self.deg/self.nodes)
    def get_kmin(self) :
        return (min(self.graph.degree()))
    def get_kmax(self) :
        return (max(self.graph.degree()))
    def get_nodes(self) :
		return self.nodes
    def get_edges(self) :
		return len(self.graph.edges())
    def get_degreerank(self) :
		self.degree_count = dict()		# DICTIONARY THAT KEEPS COUNT OF HOW MANY VERTICES ARE THERE OF EACH DEGREE
		for i in xrange(self.nodes) :
			self.degree_count[self.graph.degree(i)] = self.degree_count.get(self.graph.degree(i), 0) + 1
		self.rank = dict()				#STORES THE RANK CORRESPONDING TO EVERY DEGREE
		sum = 1
		for k in sorted(self.degree_count.keys(),reverse = True) :
			self.rank[k] = sum
			sum += self.degree_count[k]
		return self.rank	

if __name__ == "__main__" :
	f = open('data25.txt','a')
	for i in xrange(1000) :
		b = BA_Graph(i+75, int(np.random.randint(2,6,size = 1)))
		print 'TRAIN : {}'.format(i+1)        
		Train(b)
	for i in xrange(100) :
		test_node = random.randint(75,1075)
		node_for_degree = random.randint(0,test_node)
		test_attatchment = random.randint(2,6)
#		print len(training_data)
		b = BA_Graph(test_node,test_attatchment)
		#print 'K MIN : {0}\n K MAX :{1}'.format(b.get_kmin(),b.get_kmax())
		t = KNN(b.get_nodes(),b.get_edges(),b.average_degree(),b.get_kmin(),b.get_kmax(),b.graph.degree(node_for_degree),25)
		t.train(training_data)
		rank = t.test()
#		print b.graph.degree(node_for_degree)
		s = 'PREDICTED RANK : {0}\nACTUAL RANK :{1}'.format(rank,b.get_degreerank()[b.graph.degree(node_for_degree)])
		print s
		f.write(str(rank)+","+str(b.get_degreerank()[b.graph.degree(node_for_degree)])+"\n")
	f.close()
# Out:
# TRAIN : 1
# TRAIN : 2
# TRAIN : 3
# TRAIN : 4
# TRAIN : 5
# TRAIN : 6
# TRAIN : 7
# TRAIN : 8
# TRAIN : 9
# TRAIN : 10
# TRAIN : 11
# TRAIN : 12
# TRAIN : 13
# TRAIN : 14
# TRAIN : 15
# TRAIN : 16
# TRAIN : 17
# TRAIN : 18
# TRAIN : 19
# TRAIN : 20
# TRAIN : 21
# TRAIN : 22
# TRAIN : 23
# TRAIN : 24
# TRAIN : 25
# TRAIN : 26
# TRAIN : 27
# TRAIN : 28
# TRAIN : 29
# TRAIN : 30
# TRAIN : 31
# TRAIN : 32
# TRAIN : 33
# TRAIN : 34
# TRAIN : 35
# TRAIN : 36
# TRAIN : 37
# TRAIN : 38
# TRAIN : 39
# TRAIN : 40
# TRAIN : 41
# TRAIN : 42
# TRAIN : 43
# TRAIN : 44
# TRAIN : 45
# TRAIN : 46
# TRAIN : 47
# TRAIN : 48
# TRAIN : 49
# TRAIN : 50
# TRAIN : 51
# TRAIN : 52
# TRAIN : 53
# TRAIN : 54
# TRAIN : 55
# TRAIN : 56
# TRAIN : 57
# TRAIN : 58
# TRAIN : 59
# TRAIN : 60
# TRAIN : 61
# TRAIN : 62
# TRAIN : 63
# TRAIN : 64
# TRAIN : 65
# TRAIN : 66
# TRAIN : 67
# TRAIN : 68
# TRAIN : 69
# TRAIN : 70
# TRAIN : 71
# TRAIN : 72
# TRAIN : 73
# TRAIN : 74
# TRAIN : 75
# TRAIN : 76
# TRAIN : 77
# TRAIN : 78
# TRAIN : 79
# TRAIN : 80
# TRAIN : 81
# TRAIN : 82
# TRAIN : 83
# TRAIN : 84
# TRAIN : 85
# TRAIN : 86
# TRAIN : 87
# TRAIN : 88
# TRAIN : 89
# TRAIN : 90
# TRAIN : 91
# TRAIN : 92
# TRAIN : 93
# TRAIN : 94
# TRAIN : 95
# TRAIN : 96
# TRAIN : 97
# TRAIN : 98
# TRAIN : 99
# TRAIN : 100
# 1000
# PREDICTED RANK : 60.1969230769
# ACTUAL RANK :69
# 1000
# PREDICTED RANK : 244.615384615
# ACTUAL RANK :250
# 1000
# PREDICTED RANK : 187.433846154
# ACTUAL RANK :180
# 1000
# PREDICTED RANK : 371.590769231
# ACTUAL RANK :370
# 1000
# PREDICTED RANK : 106.486153846
# ACTUAL RANK :109
# 1000
# PREDICTED RANK : 55.3353846154
# ACTUAL RANK :77
# 1000
# PREDICTED RANK : 171.572307692
# ACTUAL RANK :181
# 1000
# PREDICTED RANK : 127.073846154
# ACTUAL RANK :129
# 1000
# PREDICTED RANK : 20.7446153846
# ACTUAL RANK :20
# 1000
# PREDICTED RANK : 40.0861538462
# ACTUAL RANK :55
# 1000
# PREDICTED RANK : 172.264615385
# ACTUAL RANK :173
# 1000
# PREDICTED RANK : 281.489230769
# ACTUAL RANK :281
# 1000
# PREDICTED RANK : 8.94153846154
# ACTUAL RANK :12
# 1000
# PREDICTED RANK : 352.633846154
# ACTUAL RANK :350
# 1000
# PREDICTED RANK : 395.489230769
# ACTUAL RANK :383
# 1000
# PREDICTED RANK : 203.313846154
# ACTUAL RANK :216
# 1000
# PREDICTED RANK : 80.6646153846
# ACTUAL RANK :92
# 1000
# PREDICTED RANK : 135.910769231
# ACTUAL RANK :168
# 1000
# PREDICTED RANK : 297.790769231
# ACTUAL RANK :300
# 1000
# PREDICTED RANK : 175.701538462
# ACTUAL RANK :165
# 1000
# PREDICTED RANK : 110.523076923
# ACTUAL RANK :113
# 1000
# PREDICTED RANK : 116.695384615
# ACTUAL RANK :117
# 1000
# PREDICTED RANK : 256.643076923
# ACTUAL RANK :239
# 1000
# PREDICTED RANK : 561.209230769
# ACTUAL RANK :696
# 1000
# PREDICTED RANK : 348.206153846
# ACTUAL RANK :414
# 1000
# PREDICTED RANK : 294.772307692
# ACTUAL RANK :294
# 1000
# PREDICTED RANK : 54.4369230769
# ACTUAL RANK :51
# 1000
# PREDICTED RANK : 78.0030769231
# ACTUAL RANK :81
# 1000
# PREDICTED RANK : 1.17538461538
# ACTUAL RANK :1
# 1000
# PREDICTED RANK : 95.2184615385
# ACTUAL RANK :96
# 1000
# PREDICTED RANK : 363.283076923
# ACTUAL RANK :342
# 1000
# PREDICTED RANK : 63.6215384615
# ACTUAL RANK :55
# 1000
# PREDICTED RANK : 517.446153846
# ACTUAL RANK :534
# 1000
# PREDICTED RANK : 59.36
# ACTUAL RANK :64
# 1000
# PREDICTED RANK : 210.775384615
# ACTUAL RANK :213
# 1000
# PREDICTED RANK : 109.270769231
# ACTUAL RANK :109
# 1000
# PREDICTED RANK : 106.596923077
# ACTUAL RANK :120
# 1000
# PREDICTED RANK : 419.249230769
# ACTUAL RANK :425
# 1000
# PREDICTED RANK : 240.643076923
# ACTUAL RANK :279
# 1000
# PREDICTED RANK : 210.430769231
# ACTUAL RANK :199
# 1000
# PREDICTED RANK : 218.855384615
# ACTUAL RANK :214
# 1000
# PREDICTED RANK : 293.196923077
# ACTUAL RANK :295
# 1000
# PREDICTED RANK : 6.82461538462
# ACTUAL RANK :5
# 1000
# PREDICTED RANK : 377.781538462
# ACTUAL RANK :382
# 1000
# PREDICTED RANK : 9.20307692308
# ACTUAL RANK :7
# 1000
# PREDICTED RANK : 169.421538462
# ACTUAL RANK :207
# 1000
# PREDICTED RANK : 111.187692308
# ACTUAL RANK :125
# 1000
# PREDICTED RANK : 4.46769230769
# ACTUAL RANK :4
# 1000
# PREDICTED RANK : 501.510769231
# ACTUAL RANK :522
# 1000
# PREDICTED RANK : 119.498461538
# ACTUAL RANK :136
# 1000
# PREDICTED RANK : 59.9815384615
# ACTUAL RANK :68
# 1000
# PREDICTED RANK : 690.501538462
# ACTUAL RANK :700
# 1000
# PREDICTED RANK : 219.683076923
# ACTUAL RANK :227
# 1000
# PREDICTED RANK : 187.612307692
# ACTUAL RANK :230
# 1000
# PREDICTED RANK : 190.64
# ACTUAL RANK :181
# 1000
# PREDICTED RANK : 156.683076923
# ACTUAL RANK :181
# 1000
# PREDICTED RANK : 4.21846153846
# ACTUAL RANK :5
# 1000
# PREDICTED RANK : 349.609230769
# ACTUAL RANK :359
# 1000
# PREDICTED RANK : 232.846153846
# ACTUAL RANK :227
# 1000
# PREDICTED RANK : 39.4707692308
# ACTUAL RANK :37
# 1000
# PREDICTED RANK : 544.575384615
# ACTUAL RANK :543
# 1000
# PREDICTED RANK : 124.409230769
# ACTUAL RANK :124
# 1000
# PREDICTED RANK : 19.7938461538
# ACTUAL RANK :20
# 1000
# PREDICTED RANK : 321.498461538
# ACTUAL RANK :322
# 1000
# PREDICTED RANK : 27.1630769231
# ACTUAL RANK :30
# 1000
# PREDICTED RANK : 558.72
# ACTUAL RANK :563
# 1000
# PREDICTED RANK : 43.3138461538
# ACTUAL RANK :43
# 1000
# PREDICTED RANK : 325.181538462
# ACTUAL RANK :327
# 1000
# PREDICTED RANK : 401.489230769
# ACTUAL RANK :398
# 1000
# PREDICTED RANK : 133.923076923
# ACTUAL RANK :160
# 1000
# PREDICTED RANK : 162.381538462
# ACTUAL RANK :177
# 1000
# PREDICTED RANK : 315.006153846
# ACTUAL RANK :314
# 1000
# PREDICTED RANK : 279.156923077
# ACTUAL RANK :287
# 1000
# PREDICTED RANK : 670.181538462
# ACTUAL RANK :664
# 1000
# PREDICTED RANK : 27.7569230769
# ACTUAL RANK :24
# 1000
# PREDICTED RANK : 199.984615385
# ACTUAL RANK :237
# 1000
# PREDICTED RANK : 110.550769231
# ACTUAL RANK :112
# 1000
# PREDICTED RANK : 73.9907692308
# ACTUAL RANK :82
# 1000
# PREDICTED RANK : 53.0738461538
# ACTUAL RANK :50
# 1000
# PREDICTED RANK : 93.9876923077
# ACTUAL RANK :95
# 1000
# PREDICTED RANK : 29.7169230769
# ACTUAL RANK :31
# 1000
# PREDICTED RANK : 597.873846154
# ACTUAL RANK :588
# 1000
# PREDICTED RANK : 667.470769231
# ACTUAL RANK :694
# 1000
# PREDICTED RANK : 386.978461538
# ACTUAL RANK :394
# 1000
# PREDICTED RANK : 233.689230769
# ACTUAL RANK :262
# 1000
# PREDICTED RANK : 492.747692308
# ACTUAL RANK :498
# 1000
# PREDICTED RANK : 322.821538462
# ACTUAL RANK :314
