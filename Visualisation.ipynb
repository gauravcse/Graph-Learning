# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('datanokmin1.csv')
datam = data.as_matrix()

# %%
x = datam[:,[0]]
y = datam[:,[1]]

# %%
plt.scatter(y,x)
plt.xlabel("ACTUAL RANK")
plt.ylabel("PREDICTED RANK")
plt.title("ALL VARIABLE PLOT")
linx=np.array([-50,750])
linx=np.array([-50,750])
plt.plot(linx,linx,'r-')
plt.savefig('datanokmin1.jpg')
plt.show()
